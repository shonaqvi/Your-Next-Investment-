# %%
# Initial imports
import os
import requests
import pandas as pd
from dotenv import load_dotenv
import alpaca_trade_api as tradeapi
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
# Load .env environment variables
load_dotenv()
# Out:
# True

# %%
###Set Alpaca API key and secret
alpaca_api_key = os.getenv("api_key_id")
alpaca_secret_key = os.getenv("secret_api_key")
###Create the Alpaca API object
alpaca = tradeapi.REST(
    alpaca_api_key,
    alpaca_secret_key,
    api_version="v2")

# %%
 # Verify that Alpaca key and secret were correctly loaded
print(f"Alpaca Key type: {type(alpaca_api_key)}")
print(f"Alpaca Secret Key type: {type(alpaca_secret_key)}")
# Out:
# Alpaca Key type: <class 'str'>
# Alpaca Secret Key type: <class 'str'>

# %%
###Format current date as ISO format
today = pd.Timestamp("2020-10-09", tz="America/New_York").isoformat()
###Set the tickers
tickers = ["NIO", "WKHS", "TSLA"]
###Set timeframe to '1D' for Alpaca API
timeframe = "1D"
###Get current closing prices for SPY and AGG
stocks_portfolio = alpaca.get_barset(
    tickers,
    timeframe,
    start = today,
    end = today
).df

###Preview DataFrame
stocks_portfolio
# Out:
#                              NIO                                   TSLA  \
#                             open   high    low  close    volume    open
# 2020-10-09 00:00:00-04:00  21.62  21.74  21.32  21.48  70108337  430.13
#
#                                                                     WKHS  \
#                                high       low   close    volume     open
# 2020-10-09 00:00:00-04:00  434.5899  426.4601  433.96  27687361  23.8099
#
#
#                             high    low   close    volume
# 2020-10-09 00:00:00-04:00  27.11  23.62  26.755  33059940

# %%
# Format start and end dates as ISO format for one year period
start = pd.Timestamp("2019-01-01", tz="America/New_York").isoformat()
end = pd.Timestamp("2020-10-31", tz="America/New_York").isoformat()

# %%
# Get closing prices for FB and TWTR from the last year
df_portfolio_year = alpaca.get_barset(
    tickers,
    timeframe,
    start = start,
    end = end
).df

# Display sample data
df_portfolio_year.head(10)
# Out:
#                             NIO                                       TSLA  \
#                            open    high    low   close      volume    open
# 2019-01-02 00:00:00-05:00  6.13  6.2400  6.000  6.2050   8339198.0  306.50
# 2019-01-03 00:00:00-05:00  6.10  6.1454  6.020  6.0550   6316673.0  307.00
# 2019-01-04 00:00:00-05:00  6.19  6.4000  6.130  6.3400   8818858.0  306.00
# 2019-01-07 00:00:00-05:00  6.41  6.5850  6.310  6.5000   9222915.0  321.66
# 2019-01-08 00:00:00-05:00  6.57  6.5800  6.165  6.3990   9207141.0  341.98
# 2019-01-09 00:00:00-05:00  6.41  6.6900  6.350  6.6200  10606823.0  335.50
# 2019-01-10 00:00:00-05:00  6.63  6.7300  6.410  6.6650   9592003.0  334.40
# 2019-01-11 00:00:00-05:00  6.50  6.6150  6.480  6.5816   6626062.0  342.09
# 2019-01-14 00:00:00-05:00  6.51  7.1500  6.370  6.7700  19131104.0  342.50
# 2019-01-15 00:00:00-05:00  6.85  7.0700  6.750  6.8400  11449718.0  335.00
#
#                                                                      WKHS  \
#                                high       low     close    volume    open
# 2019-01-02 00:00:00-05:00  315.1300  298.8000  309.8699  10751296  0.5700
# 2019-01-03 00:00:00-05:00  309.4000  297.3800  300.3100   6672221  0.6700
# 2019-01-04 00:00:00-05:00  318.0000  302.7300  317.5400   6983846  0.7665
# 2019-01-07 00:00:00-05:00  336.7400  317.7508  334.9860   7193888  0.8000
# 2019-01-08 00:00:00-05:00  344.0100  327.0200  335.4900   6567180  0.7900
# 2019-01-09 00:00:00-05:00  343.5025  331.4700  338.5200   5199244  0.7700
# 2019-01-10 00:00:00-05:00  345.3900  331.7900  344.9100   5719942  0.7315
# 2019-01-11 00:00:00-05:00  348.4100  338.7700  347.3500   4796324  0.7101
# 2019-01-14 00:00:00-05:00  342.5000  334.0000  334.7000   5009149  0.8000
# 2019-01-15 00:00:00-05:00  348.8000  334.5000  344.3450   5803044  0.8000
#
#
#                              high     low   close    volume
# 2019-01-02 00:00:00-05:00  0.7100  0.5545  0.6501  534006.0
# 2019-01-03 00:00:00-05:00  0.7300  0.6600  0.6950  319398.0
# 2019-01-04 00:00:00-05:00  0.7990  0.7500  0.7990  448176.0
# 2019-01-07 00:00:00-05:00  0.8000  0.7600  0.7800  126486.0
# 2019-01-08 00:00:00-05:00  0.7900  0.7400  0.7599  151570.0
# 2019-01-09 00:00:00-05:00  0.7790  0.7400  0.7466  111366.0
# 2019-01-10 00:00:00-05:00  0.7423  0.7031  0.7100   97576.0
# 2019-01-11 00:00:00-05:00  0.7900  0.6900  0.7801  208087.0
# 2019-01-14 00:00:00-05:00  0.8199  0.7500  0.7800  497417.0
# 2019-01-15 00:00:00-05:00  0.8351  0.7800  0.8251  245630.0

# %%
# Create an empty DataFrame for closing prices
df_closing_prices = pd.DataFrame()

# Fetch the closing prices of FB and TWTR
df_closing_prices["NIO"] = df_portfolio_year["NIO"]["close"]
df_closing_prices["WKHS"] = df_portfolio_year["WKHS"]["close"]
df_closing_prices["TSLA"] = df_portfolio_year["TSLA"]["close"]

# Drop the time component of the date
df_closing_prices.index = df_closing_prices.index.date

# Display sample data
df_closing_prices.head(10)
# Out:
#                NIO    WKHS      TSLA
# 2019-01-02  6.2050  0.6501  309.8699
# 2019-01-03  6.0550  0.6950  300.3100
# 2019-01-04  6.3400  0.7990  317.5400
# 2019-01-07  6.5000  0.7800  334.9860
# 2019-01-08  6.3990  0.7599  335.4900
# 2019-01-09  6.6200  0.7466  338.5200
# 2019-01-10  6.6650  0.7100  344.9100
# 2019-01-11  6.5816  0.7801  347.3500
# 2019-01-14  6.7700  0.7800  334.7000
# 2019-01-15  6.8400  0.8251  344.3450

# %%
df_daily_return = df_closing_prices.pct_change()
df_daily_return = df_daily_return.dropna()
df_daily_return.head()
# Out:
#                  NIO      WKHS      TSLA
# 2019-01-03 -0.024174  0.069066 -0.030851
# 2019-01-04  0.047069  0.149640  0.057374
# 2019-01-07  0.025237 -0.023780  0.054941
# 2019-01-08 -0.015538 -0.025769  0.001505
# 2019-01-09  0.034537 -0.017502  0.009032

# %%
df_daily_return.dtypes
# Out:
# NIO     float64
# WKHS    float64
# TSLA    float64
# dtype: object

# %%
df_daily_return.plot(figsize=(10,5))

# %%
df_cumulative = (1 + df_daily_return).cumprod()
df_cumulative.plot(figsize=(10,5))

# %%
df_cumulative.plot.box(figsize=(20,10))

# %%
portfolio_std = df_daily_return.std()
portfolio_std
# Out:
# NIO     0.066849
# WKHS    0.122681
# TSLA    0.058396
# dtype: float64

# %%
annualized_std = df_daily_return * np.sqrt(252)
annualized_std.rolling(window=21).std().plot(figsize=(20,10))

# %%
sharpe_ratios = (df_daily_return.mean() * 252) / (df_daily_return.std() * np.sqrt(252))
sharpe_ratios.plot(kind="bar")

# %%
###Format current date as ISO format
start = pd.Timestamp("2019-01-01", tz="America/New_York").isoformat()
end = pd.Timestamp("2020-10-31", tz="America/New_York").isoformat()
###Set the tickers
tickers = ["AMZN", "MSFT", "MRNA", "NVDA", "ZM"]
###Set timeframe to '1D' for Alpaca API
timeframe = "1D"
###Get current closing prices for SPY and AGG
best_stocks_portfolio = alpaca.get_barset(
    tickers,
    timeframe,
    start = start,
    end = end
).df

###Preview DataFrame
best_stocks_portfolio.head()
# Out:
#                               AMZN                                         \
#                               open     high        low     close   volume
# 2019-01-02 00:00:00-05:00  1465.20  1553.36  1460.9300  1536.730  7132821
# 2019-01-03 00:00:00-05:00  1520.01  1538.00  1498.1062  1502.070  6340704
# 2019-01-04 00:00:00-05:00  1530.00  1594.00  1518.3100  1574.540  8285596
# 2019-01-07 00:00:00-05:00  1602.31  1634.56  1589.1850  1631.120  7252880
# 2019-01-08 00:00:00-05:00  1664.69  1676.61  1616.6100  1655.835  8184304
#
#                             MRNA                                    ...  \
#                             open    high      low   close   volume  ...
# 2019-01-02 00:00:00-05:00  14.93  15.300  14.5100  15.290  2038570  ...
# 2019-01-03 00:00:00-05:00  15.49  16.080  15.2000  15.510  1557024  ...
# 2019-01-04 00:00:00-05:00  16.00  17.500  15.8944  16.975  1630720  ...
# 2019-01-07 00:00:00-05:00  17.54  17.940  16.1800  16.350  1548625  ...
# 2019-01-08 00:00:00-05:00  17.35  17.468  16.0500  16.950  1809302  ...
#
#                              NVDA                                       ZM  \
#                              open    high       low   close    volume open
# 2019-01-02 00:00:00-05:00  130.64  138.48  130.0500  136.00  10849501  NaN
# 2019-01-03 00:00:00-05:00  133.79  135.16  127.6932  128.37  15496092  NaN
# 2019-01-04 00:00:00-05:00  130.94  137.73  129.7000  135.85  13378304  NaN
# 2019-01-07 00:00:00-05:00  138.50  144.89  136.4300  143.61  16318300  NaN
# 2019-01-08 00:00:00-05:00  146.69  146.78  136.9000  139.60  18128834  NaN
#
#
#                           high low close volume
# 2019-01-02 00:00:00-05:00  NaN NaN   NaN    NaN
# 2019-01-03 00:00:00-05:00  NaN NaN   NaN    NaN
# 2019-01-04 00:00:00-05:00  NaN NaN   NaN    NaN
# 2019-01-07 00:00:00-05:00  NaN NaN   NaN    NaN
# 2019-01-08 00:00:00-05:00  NaN NaN   NaN    NaN
#
# [5 rows x 25 columns]

# %%
# Create an empty DataFrame for closing prices
df_best_stocks = pd.DataFrame()

# Fetch the closing prices of FB and TWTR
df_best_stocks["AMZN"] = best_stocks_portfolio["AMZN"]["close"]
df_best_stocks["MRNA"] = best_stocks_portfolio["MRNA"]["close"]
df_best_stocks["MSFT"] = best_stocks_portfolio["MSFT"]["close"]
df_best_stocks["NVDA"] = best_stocks_portfolio["NVDA"]["close"]
df_best_stocks["ZM"] = best_stocks_portfolio["ZM"]["close"]

# Drop the time component of the date
df_best_stocks.index = df_best_stocks.index.date

# Display sample data
df_best_stocks.head(10)
# Out:
#                  AMZN    MRNA     MSFT     NVDA  ZM
# 2019-01-02  1536.7300  15.290  101.010  136.000 NaN
# 2019-01-03  1502.0700  15.510   97.500  128.370 NaN
# 2019-01-04  1574.5400  16.975  101.775  135.850 NaN
# 2019-01-07  1631.1200  16.350  102.150  143.610 NaN
# 2019-01-08  1655.8350  16.950  102.730  139.600 NaN
# 2019-01-09  1657.5900  16.270  104.250  142.590 NaN
# 2019-01-10  1655.5000  16.485  103.570  145.300 NaN
# 2019-01-11  1639.6600  16.960  102.810  148.910 NaN
# 2019-01-14  1619.8767  16.740  102.120  150.745 NaN
# 2019-01-15  1672.7500  16.610  104.780  149.500 NaN

# %%
##Join stocks
all_portfolios = pd.concat([df_best_stocks, df_closing_prices], axis="columns", join="inner")
all_portfolios.head()
# Out:
#                 AMZN    MRNA     MSFT    NVDA  ZM    NIO    WKHS      TSLA
# 2019-01-02  1536.730  15.290  101.010  136.00 NaN  6.205  0.6501  309.8699
# 2019-01-03  1502.070  15.510   97.500  128.37 NaN  6.055  0.6950  300.3100
# 2019-01-04  1574.540  16.975  101.775  135.85 NaN  6.340  0.7990  317.5400
# 2019-01-07  1631.120  16.350  102.150  143.61 NaN  6.500  0.7800  334.9860
# 2019-01-08  1655.835  16.950  102.730  139.60 NaN  6.399  0.7599  335.4900

# %%
all_daily_return = all_portfolios.pct_change()
all_daily_return.head()
# Out:
#                 AMZN      MRNA      MSFT      NVDA  ZM       NIO      WKHS  \
# 2019-01-02       NaN       NaN       NaN       NaN NaN       NaN       NaN
# 2019-01-03 -0.022554  0.014388 -0.034749 -0.056103 NaN -0.024174  0.069066
# 2019-01-04  0.048247  0.094455  0.043846  0.058269 NaN  0.047069  0.149640
# 2019-01-07  0.035934 -0.036819  0.003685  0.057122 NaN  0.025237 -0.023780
# 2019-01-08  0.015152  0.036697  0.005678 -0.027923 NaN -0.015538 -0.025769
#
#                 TSLA
# 2019-01-02       NaN
# 2019-01-03 -0.030851
# 2019-01-04  0.057374
# 2019-01-07  0.054941
# 2019-01-08  0.001505

# %%
all_daily_return = all_daily_return.dropna().copy()
all_daily_return
# Out:
#                 AMZN      MRNA      MSFT      NVDA        ZM       NIO  \
# 2019-04-22  0.014312  0.048602  0.003161  0.011541  0.051426 -0.001045
# 2019-04-23  0.019136  0.047196  0.013575  0.011780  0.052110  0.008368
# 2019-04-24 -0.012104  0.040825 -0.002790  0.002622 -0.084721  0.037344
# 2019-04-25  0.000673 -0.000388  0.031897 -0.022650  0.028797 -0.022000
# 2019-04-26  0.025624  0.016706  0.006275 -0.046832  0.018456  0.004090
# ...              ...       ...       ...       ...       ...       ...
# 2020-10-26  0.000836 -0.003262 -0.028253 -0.033029  0.012258 -0.042342
# 2020-10-27  0.025130  0.005692  0.014276  0.019148  0.040943  0.093810
# 2020-10-28 -0.038149 -0.069902 -0.048980 -0.057250 -0.043415 -0.032689
# 2020-10-29  0.015905  0.083219  0.008288  0.030829 -0.049943  0.162791
# 2020-10-30 -0.054986 -0.052247 -0.008856 -0.035026 -0.059081 -0.044687
#
#                 WKHS      TSLA
# 2019-04-22  0.015597 -0.037933
# 2019-04-23  0.145557  0.004130
# 2019-04-24  0.103125 -0.020037
# 2019-04-25  0.033994 -0.042976
# 2019-04-26  0.200848 -0.050623
# ...              ...       ...
# 2020-10-26 -0.088496 -0.000796
# 2020-10-27 -0.071197  0.009972
# 2020-10-28 -0.027294 -0.043515
# 2020-10-29  0.030448  0.011429
# 2020-10-30 -0.108922 -0.055036
#
# [388 rows x 8 columns]

# %%
all_daily_return.plot(figsize=(10,5))

# %%
all_cumulative = (1 + all_daily_return).cumprod()
all_cumulative.plot(figsize=(10,5))

# %%
all_cumulative.plot.box(figsize=(20,10))

# %%
all_portfolio_std = all_daily_return.std()
all_portfolio_std
# Out:
# AMZN    0.020756
# MRNA    0.052370
# MSFT    0.023377
# NVDA    0.032542
# ZM      0.047479
# NIO     0.070091
# WKHS    0.131732
# TSLA    0.062325
# dtype: float64

# %%
all_annualized_std = all_daily_return * np.sqrt(252)
all_annualized_std.rolling(window=21).std().plot(figsize=(20,10))

# %%
###Calculate and plot the correlation
all_correlation = all_portfolios.corr()
all_correlation
# Out:
#           AMZN      MRNA      MSFT      NVDA        ZM       NIO      WKHS  \
# AMZN  1.000000  0.932956  0.914474  0.961780  0.903810  0.809663  0.887625
# MRNA  0.932956  1.000000  0.857727  0.915606  0.834294  0.725533  0.773316
# MSFT  0.914474  0.857727  1.000000  0.936493  0.821407  0.619475  0.786173
# NVDA  0.961780  0.915606  0.936493  1.000000  0.924771  0.818768  0.886534
# ZM    0.903810  0.834294  0.821407  0.924771  1.000000  0.949147  0.910208
# NIO   0.809663  0.725533  0.619475  0.818768  0.949147  1.000000  0.862907
# WKHS  0.887625  0.773316  0.786173  0.886534  0.910208  0.862907  1.000000
# TSLA  0.678757  0.705368  0.709170  0.628400  0.344288  0.333526  0.437934
#
#           TSLA
# AMZN  0.678757
# MRNA  0.705368
# MSFT  0.709170
# NVDA  0.628400
# ZM    0.344288
# NIO   0.333526
# WKHS  0.437934
# TSLA  1.000000

# %%
sns.heatmap(all_correlation, vmin=-1, vmax=1)

# %%
all_sharpe_ratios = (all_daily_return.mean() * 252) / (all_daily_return.std() * np.sqrt(252))
all_sharpe_ratios.plot(kind="bar")
