# %%
import panel as pn
pn.extension('plotly')
import plotly.express as px
import pandas as pd
import hvplot.pandas
import matplotlib.pyplot as plt
import os
from pathlib import Path
from dotenv import load_dotenv
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
file_path = Path("top_model_data.csv")
ev_sale = pd.read_csv(file_path, index_col="Top 10 car Model")
ev_sale["Sales in thousand unit"]= ev_sale["Sales in thousand unit"].astype("float")["Sales in thousand unit"]=ev_sale["Sales in thousand unit"].astype("float")
ev_sale=ev_sale.sort_values("Sales in thousand unit")

# %%
ev_sale.head(10)
# Out:
#                   Sales in thousand unit
# Top 10 car Model
# BMW i3                             41.84
# Hyundai Kona                       44.39
# Renault                            46.84
# Mitsubishi PHEV                    49.65
# BMW 530e                           51.08
# SAIC                               60.05
# BYD Yuan EV                        67.84
# Nissan Leaf                        69.87
# BAIC EU Series                    111.05
# Tesla Model 3                     300.08

# %%
#ev_sale.hvplot.area(x='Top 10 car Model', y=['Sales in thousand unit'], color= "green")
#ev_sale.plot(kind="pie", y="Sales in thousand unit",figsize=(20,10))
ev_sale.plot.pie(autopct="%.1f%%",title="Top 10 Car Model Sales in 2019", subplots=True,figsize=(15,12))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000205952DEAC8>],
#       dtype=object)

# %%
ev_sale.hvplot.bar(rot= 90,height=450,width=450,x='Top 10 car Model',color="gold").opts(bgcolor="White")
# Out:
# :Bars   [Top 10 car Model]   (Sales in thousand unit)
