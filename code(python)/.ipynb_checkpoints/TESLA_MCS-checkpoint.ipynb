# %%
import datetime as dt
from pathlib import Path
import seaborn as sns
import os
import requests
import pandas as pd
from dotenv import load_dotenv
import alpaca_trade_api as tradeapi
from MCForecastTools import MCSimulation
# %matplotlib inline

# %%
load_dotenv()
# Out:
# True

# %%
###Set Alpaca API key and secret
alpaca_api_key = os.getenv("api_key_id")
alpaca_secret_key = os.getenv("secret_api_key")
###Create the Alpaca API object
alpaca = tradeapi.REST(
    alpaca_api_key,
    alpaca_secret_key,
    api_version="v2")

# %%
###Set the tickers
tickers = ["TSLA"]
###Set timeframe to '1D' for Alpaca API
timeframe = "1D"
# Set start and end datetimes 
start_date = pd.Timestamp("2015-01-01", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2020-08-27", tz="America/New_York").isoformat()

# Get historical data 
df_ticker = alpaca.get_barset(
    tickers,
    timeframe,
    start=start_date,
    end=end_date
).df

df_ticker.tail(10)
# Out:
#                                TSLA
#                                open     high        low     close    volume
# 2020-08-14 00:00:00-04:00  1664.990  1668.80  1626.6400  1651.500  11738513
# 2020-08-17 00:00:00-04:00  1677.000  1845.86  1672.8300  1835.860  19482112
# 2020-08-18 00:00:00-04:00  1898.990  1923.90  1845.1100  1888.110  15300121
# 2020-08-19 00:00:00-04:00  1865.000  1911.00  1841.2100  1879.000  11776286
# 2020-08-20 00:00:00-04:00  1860.680  2021.99  1857.0600  2001.300  20432043
# 2020-08-21 00:00:00-04:00  2044.760  2095.49  2025.0500  2050.000  20572968
# 2020-08-24 00:00:00-04:00  2126.275  2129.00  1927.5200  2015.695  19295383
# 2020-08-25 00:00:00-04:00  1974.890  2027.95  1968.0000  2024.090  10051608
# 2020-08-26 00:00:00-04:00  2060.000  2166.00  2053.6292  2151.930  13768358
# 2020-08-27 00:00:00-04:00  2180.460  2295.60  2142.5000  2239.760  23059123

# %%
# Set number of simulations
num_sims = 1000

# Configure a Monte Carlo simulation to forecast 5 years daily returns
MC_5y = MCSimulation(
    portfolio_data = df_ticker,
    weights = [1],
    num_simulation = num_sims,
    num_trading_days = 252*5
)
MC_5y.portfolio_data.head()
# Out:
#                              TSLA                                       \
#                              open      high       low   close   volume
# 2015-01-02 00:00:00-05:00  222.87  223.2500  213.2600  219.19  3943826
# 2015-01-05 00:00:00-05:00  214.55  216.5000  207.1626  210.01  4577520
# 2015-01-06 00:00:00-05:00  210.06  214.2000  204.2100  211.19  5383509
# 2015-01-07 00:00:00-05:00  213.35  214.7800  209.7800  210.81  2582044
# 2015-01-08 00:00:00-05:00  212.81  213.7999  210.0100  210.55  2922730
#
#
#                           daily_return
# 2015-01-02 00:00:00-05:00          NaN
# 2015-01-05 00:00:00-05:00    -0.041881
# 2015-01-06 00:00:00-05:00     0.005619
# 2015-01-07 00:00:00-05:00    -0.001799
# 2015-01-08 00:00:00-05:00    -0.001233

# %%
MC_5y.calc_cumulative_return()
# Out:
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# Running Monte Carlo simulation number 100.
# Running Monte Carlo simulation number 110.
# Running Monte Carlo simulation number 120.
# Running Monte Carlo simulation number 130.
# Running Monte Carlo simulation number 140.
# Running Monte Carlo simulation number 150.
# Running Monte Carlo simulation number 160.
# Running Monte Carlo simulation number 170.
# Running Monte Carlo simulation number 180.
# Running Monte Carlo simulation number 190.
# Running Monte Carlo simulation number 200.
# Running Monte Carlo simulation number 210.
# ...

# %%
 # Plot probability distribution and confidence intervals
dist_plot_5y = MC_5y.plot_distribution()

# Save the plot for future usage
dist_plot_5y.get_figure().savefig('MC_fiveyear_dist_plot.png',bbox_inches='tight')

# %%
 # Fetch summary statistics from the Monte Carlo simulation results
tbl_5y = MC_5y.summarize_cumulative_return()

# Print summary statistics
print(tbl_5y)
# Out:
# count           1000.000000
# mean              16.004116
# std               29.964895
# min                0.279522
# 25%                3.804462
# 50%                8.194131
# 75%               17.529564
# max              533.248602
# 95% CI Lower       0.793857
# 95% CI Upper      82.577469
# Name: 1260, dtype: float64

# %%
 # Use the lower and upper `95%` confidence intervals to calculate the range of the possible outcomes of our $10,000 investments in Tesla stocks
ci_lower_5y = round(tbl_5y[8]*10000,2)
ci_upper_5y = round(tbl_5y[9]*10000,2)

# Print results
print(f"There is a 95% chance that an initial investment of $10,000 in the portfolio"
      f" over the next 5 years will end within the range of"
      f" ${ci_lower_5y} and ${ci_upper_5y}")
# Out:
# There is a 95% chance that an initial investment of $10,000 in the portfolio over the next 5 years will end within the range of $7938.57 and $825774.69

# %%
# Set number of simulations
num_sims = 1000

# Configure a Monte Carlo simulation to forecast 10 years daily returns
MC_10y = MCSimulation(
    portfolio_data = df_ticker,
    weights = [1],
    num_simulation = num_sims,
    num_trading_days = 252*10
)
MC_10y.portfolio_data.head()
# Out:
#                              TSLA                                       \
#                              open      high       low   close   volume
# 2015-01-02 00:00:00-05:00  222.87  223.2500  213.2600  219.19  3943826
# 2015-01-05 00:00:00-05:00  214.55  216.5000  207.1626  210.01  4577520
# 2015-01-06 00:00:00-05:00  210.06  214.2000  204.2100  211.19  5383509
# 2015-01-07 00:00:00-05:00  213.35  214.7800  209.7800  210.81  2582044
# 2015-01-08 00:00:00-05:00  212.81  213.7999  210.0100  210.55  2922730
#
#
#                           daily_return
# 2015-01-02 00:00:00-05:00          NaN
# 2015-01-05 00:00:00-05:00    -0.041881
# 2015-01-06 00:00:00-05:00     0.005619
# 2015-01-07 00:00:00-05:00    -0.001799
# 2015-01-08 00:00:00-05:00    -0.001233

# %%
MC_10y.calc_cumulative_return()
# Out:
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# Running Monte Carlo simulation number 100.
# Running Monte Carlo simulation number 110.
# Running Monte Carlo simulation number 120.
# Running Monte Carlo simulation number 130.
# Running Monte Carlo simulation number 140.
# Running Monte Carlo simulation number 150.
# Running Monte Carlo simulation number 160.
# Running Monte Carlo simulation number 170.
# Running Monte Carlo simulation number 180.
# Running Monte Carlo simulation number 190.
# Running Monte Carlo simulation number 200.
# Running Monte Carlo simulation number 210.
# ...

# %%
 # Plot probability distribution and confidence intervals
dist_plot_10y = MC_10y.plot_distribution()

# Save the plot for future usage
dist_plot_10y.get_figure().savefig('MC_fiveyear_dist_plot.png',bbox_inches='tight')

# %%
 # Fetch summary statistics from the Monte Carlo simulation results
tbl_10y = MC_10y.summarize_cumulative_return()

# Print summary statistics
print(tbl_10y)
# Out:
# count           1000.000000
# mean             276.924566
# std              689.065237
# min                0.140782
# 25%               21.167925
# 50%               71.447996
# 75%              222.559914
# max             9073.523149
# 95% CI Lower       2.781397
# 95% CI Upper    2022.890218
# Name: 2520, dtype: float64

# %%
 # Use the lower and upper `95%` confidence intervals to calculate the range of the possible outcomes of our $10,000 investments in Tesla stocks
ci_lower_10y = round(tbl_10y[8]*10000,2)
ci_upper_10y = round(tbl_10y[9]*10000,2)

# Print results
print(f"There is a 95% chance that an initial investment of $10,000 in the portfolio"
      f" over the next 5 years will end within the range of"
      f" ${ci_lower_10y} and ${ci_upper_10y}")
# Out:
# There is a 95% chance that an initial investment of $10,000 in the portfolio over the next 5 years will end within the range of $27813.97 and $20228902.18

# %%
# Set number of simulations
num_sims = 1000

# Configure a Monte Carlo simulation to forecast 20 years daily returns
MC_20y = MCSimulation(
    portfolio_data = df_ticker,
    weights = [1],
    num_simulation = num_sims,
    num_trading_days = 252*20
)
MC_20y.portfolio_data.head()
# Out:
#                              TSLA                                       \
#                              open      high       low   close   volume
# 2015-01-02 00:00:00-05:00  222.87  223.2500  213.2600  219.19  3943826
# 2015-01-05 00:00:00-05:00  214.55  216.5000  207.1626  210.01  4577520
# 2015-01-06 00:00:00-05:00  210.06  214.2000  204.2100  211.19  5383509
# 2015-01-07 00:00:00-05:00  213.35  214.7800  209.7800  210.81  2582044
# 2015-01-08 00:00:00-05:00  212.81  213.7999  210.0100  210.55  2922730
#
#
#                           daily_return
# 2015-01-02 00:00:00-05:00          NaN
# 2015-01-05 00:00:00-05:00    -0.041881
# 2015-01-06 00:00:00-05:00     0.005619
# 2015-01-07 00:00:00-05:00    -0.001799
# 2015-01-08 00:00:00-05:00    -0.001233

# %%
MC_20y.calc_cumulative_return()
# Out:
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# Running Monte Carlo simulation number 100.
# Running Monte Carlo simulation number 110.
# Running Monte Carlo simulation number 120.
# Running Monte Carlo simulation number 130.
# Running Monte Carlo simulation number 140.
# Running Monte Carlo simulation number 150.
# Running Monte Carlo simulation number 160.
# Running Monte Carlo simulation number 170.
# Running Monte Carlo simulation number 180.
# Running Monte Carlo simulation number 190.
# Running Monte Carlo simulation number 200.
# Running Monte Carlo simulation number 210.
# ...

# %%
 # Plot probability distribution and confidence intervals
dist_plot_20y = MC_20y.plot_distribution()

# Save the plot for future usage
dist_plot_20y.get_figure().savefig('MC_fiveyear_dist_plot.png',bbox_inches='tight')

# %%
 # Fetch summary statistics from the Monte Carlo simulation results
tbl_20y = MC_20y.summarize_cumulative_return()

# Print summary statistics
print(tbl_20y)
# Out:
# count           1.000000e+03
# mean            5.691734e+04
# std             3.301432e+05
# min             1.190786e+00
# 25%             7.669214e+02
# 50%             3.727141e+03
# 75%             1.757290e+04
# max             8.930958e+06
# 95% CI Lower    3.158316e+01
# 95% CI Upper    5.011193e+05
# Name: 5040, dtype: float64

# %%
 # Use the lower and upper `95%` confidence intervals to calculate the range of the possible outcomes of our $10,000 investments in Tesla stocks
ci_lower_20y = round(tbl_20y[8]*10000,2)
ci_upper_20y = round(tbl_20y[9]*10000,2)

# Print results
print(f"There is a 95% chance that an initial investment of $10,000 in the portfolio"
      f" over the next 5 years will end within the range of"
      f" ${ci_lower_20y} and ${ci_upper_20y}")
# Out:
# There is a 95% chance that an initial investment of $10,000 in the portfolio over the next 5 years will end within the range of $315831.64 and $5011193448.81

# %%
print("Financial Analysis")
print("----------------------------TESLA STOCK PRICE OVER NEXT 5 YEARS----------------------------")
print(f"There is a 95% chance that an initial investment of $10,000 in the portfolio"
      f" over the next 5 years will end within the range of"
      f" ${ci_lower_5y} and ${ci_upper_5y}")
print("----------------------------TESLA STOCK PRICE OVER NEXT 10 YEARS----------------------------")
print(f"There is a 95% chance that an initial investment of $10,000 in the portfolio"
      f" over the next 5 years will end within the range of"
      f" ${ci_lower_10y} and ${ci_upper_10y}")
print("----------------------------TESLA STOCK PRICE OVER NEXT 2O YEARS----------------------------")
print(f"There is a 95% chance that an initial investment of $10,000 in the portfolio"
      f" over the next 5 years will end within the range of"
      f" ${ci_lower_20y} and ${ci_upper_20y}")
# Out:
# Financial Analysis
# ----------------------------TESLA STOCK PRICE OVER NEXT 5 YEARS----------------------------
# There is a 95% chance that an initial investment of $10,000 in the portfolio over the next 5 years will end within the range of $7938.57 and $825774.69
# ----------------------------TESLA STOCK PRICE OVER NEXT 10 YEARS----------------------------
# There is a 95% chance that an initial investment of $10,000 in the portfolio over the next 5 years will end within the range of $27813.97 and $20228902.18
# ----------------------------TESLA STOCK PRICE OVER NEXT 2O YEARS----------------------------
# There is a 95% chance that an initial investment of $10,000 in the portfolio over the next 5 years will end within the range of $315831.64 and $5011193448.81
